# %%
import pandas as pd
import numpy as np
import os

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
yr0 = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/GridExport00_July_17_2025_22_43_46.xlsx', engine='openpyxl')
yr1 = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/GridExport01_July_17_2025_22_35_47.xlsx', engine='openpyxl')
yr2 = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/GridExport02_July_18_2025_0_6_42.xlsx', engine='openpyxl')
yr3 = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/GridExport03_July_18_2025_0_41_11.xlsx', engine='openpyxl')

# %%
ESG_Table_for_ALWA_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ALWA.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ALWA_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ALWA.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ALWA_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ALWA.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ALWA_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ALWA.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ANTO_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ANTO.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ANTO_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ANTO.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ANTO_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ANTO.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ANTO_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ANTO.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_AHT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AHT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_AHT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AHT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_AHT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AHT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_AHT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AHT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SVT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SVT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SVT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SVT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SVT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SVT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SVT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SVT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BARC_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BARC.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BARC_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BARC.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BARC_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BARC.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BARC_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BARC.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BTRW_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BTRW.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BTRW_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BTRW.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BTRW_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BTRW.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BTRW_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BTRW.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BAB_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAB.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BAB_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAB.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BAB_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAB.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BAB_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAB.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BP_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BP.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BP_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BP.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BP_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BP.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BP_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BP.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BNZL_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BNZL.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BNZL_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BNZL.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BNZL_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BNZL.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BNZL_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BNZL.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_CNA_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CNA.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_CNA_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CNA.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_CNA_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CNA.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_CNA_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CNA.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_AV_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AV.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_AV_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AV.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_AV_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AV.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_AV_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AV.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_CRDA_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CRDA.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_CRDA_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CRDA.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_CRDA_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CRDA.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_CRDA_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CRDA.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_DCC_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DCC.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_DCC_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DCC.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_DCC_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DCC.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_DCC_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DCC.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BAES_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAES.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BAES_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAES.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BAES_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAES.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BAES_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BAES.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_DPLM_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DPLM.L (2).xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_DPLM_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DPLM.L (2).xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_DPLM_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DPLM.L (2).xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_DPLM_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DPLM.L (2).xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_FCIT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FCIT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_FCIT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FCIT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_FCIT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FCIT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_FCIT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FCIT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ABF_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ABF.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ABF_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ABF.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ABF_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ABF.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ABF_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ABF.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_GAW_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GAW.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_GAW_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GAW.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_GAW_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GAW.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_GAW_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GAW.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_EXPN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EXPN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_EXPN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EXPN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_EXPN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EXPN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_EXPN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EXPN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_DGE_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DGE.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_DGE_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DGE.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_DGE_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DGE.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_DGE_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for DGE.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_HLMA_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLMA.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_HLMA_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLMA.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_HLMA_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLMA.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_HLMA_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLMA.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_NXT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NXT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_NXT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NXT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_NXT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NXT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_NXT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NXT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_PCT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PCT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_PCT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PCT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_PCT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PCT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_PCT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PCT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_HSX_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSX.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_HSX_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSX.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_HSX_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSX.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_HSX_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSX.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_IMB_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IMB.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_IMB_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IMB.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_IMB_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IMB.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_IMB_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IMB.L.xlsx', engine='openpyxl', sheet_name='Controversies')
SG_Table_for_JD_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for JD.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_JD_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for JD.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_JD_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for JD.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_JD_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for JD.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_LGEN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LGEN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_LGEN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LGEN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_LGEN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LGEN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_LGEN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LGEN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_HWDN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HWDN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_HWDN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HWDN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_HWDN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HWDN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_HWDN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HWDN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_UU_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UU.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_UU_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UU.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_UU_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UU.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_UU_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UU.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_PSON_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSON.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_PSON_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSON.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_PSON_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSON.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_PSON_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSON.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_PSN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_PSN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_PSN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_PSN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_PRU_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PRU.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_PRU_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PRU.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_PRU_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PRU.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_PRU_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PRU.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_RIO_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RIO.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_RIO_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RIO.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_RIO_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RIO.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_RIO_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RIO.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_VOD_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for VOD.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_VOD_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for VOD.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_VOD_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for VOD.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_VOD_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for VOD.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_RKT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RKT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_RKT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RKT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_RKT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RKT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_RKT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RKT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_REL_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for REL.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_REL_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for REL.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_REL_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for REL.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_REL_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for REL.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_RTO_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RTO.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_RTO_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RTO.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_RTO_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RTO.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_RTO_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RTO.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_NWG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NWG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_NWG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NWG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_NWG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NWG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_NWG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NWG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SJP_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SJP.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SJP_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SJP.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SJP_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SJP.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SJP_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SJP.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SBRY_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SBRY.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SBRY_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SBRY.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SBRY_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SBRY.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SBRY_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SBRY.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SDR_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SDR.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SDR_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SDR.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SDR_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SDR.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SDR_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SDR.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SMT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SMT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SMT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SMT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SSE_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SSE.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SSE_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SSE.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SSE_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SSE.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SSE_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SSE.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SGE_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGE.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SGE_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGE.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SGE_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGE.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SGE_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGE.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SGRO_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGRO.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SGRO_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGRO.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SGRO_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGRO.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SGRO_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SGRO.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SMIN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMIN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SMIN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMIN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SMIN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMIN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SMIN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SMIN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SPX_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SPX.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SPX_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SPX.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SPX_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SPX.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SPX_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SPX.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_STAN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for STAN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_STAN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for STAN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_STAN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for STAN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_STAN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for STAN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_LLOY_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LLOY.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_LLOY_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LLOY.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_LLOY_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LLOY.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_LLOY_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LLOY.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_TW_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TW.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_TW_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TW.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_TW_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TW.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_TW_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TW.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_TSCO_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TSCO.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_TSCO_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TSCO.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_TSCO_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TSCO.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_TSCO_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for TSCO.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_III_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for III.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_III_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for III.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_III_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for III.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_III_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for III.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_WEIR_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WEIR.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_WEIR_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WEIR.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_WEIR_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WEIR.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_WEIR_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WEIR.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_WPP_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WPP.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_WPP_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WPP.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_WPP_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WPP.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_WPP_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WPP.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_AZN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AZN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_AZN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AZN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_AZN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AZN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_AZN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AZN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_KGF_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for KGF.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_KGF_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for KGF.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_KGF_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for KGF.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_KGF_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for KGF.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BATS_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BATS.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BATS_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BATS.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BATS_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BATS.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BATS_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BATS.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ULVR_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ULVR.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ULVR_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ULVR.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ULVR_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ULVR.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ULVR_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ULVR.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_HSBA_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSBA.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_HSBA_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSBA.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_HSBA_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSBA.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_HSBA_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HSBA.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_INF_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for INF.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_INF_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for INF.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_INF_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for INF.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_INF_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for INF.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_AAL_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAL.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_AAL_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAL.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_AAL_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAL.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_AAL_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAL.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_GSK_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GSK.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_GSK_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GSK.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_GSK_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GSK.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_GSK_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GSK.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_UTG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UTG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_UTG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UTG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_UTG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UTG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_UTG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for UTG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_CPG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CPG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_CPG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CPG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_CPG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CPG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_CPG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CPG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_WTB_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WTB.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_WTB_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WTB.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_WTB_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WTB.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_WTB_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for WTB.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_EZJ_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EZJ.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_EZJ_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EZJ.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_EZJ_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EZJ.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_EZJ_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EZJ.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_LSEG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LSEG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_LSEG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LSEG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_LSEG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LSEG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_LSEG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LSEG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_NG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_NG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_NG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_NG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for NG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_MKS_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MKS.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_MKS_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MKS.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_MKS_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MKS.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_MKS_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MKS.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ITRK_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ITRK.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ITRK_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ITRK.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ITRK_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ITRK.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ITRK_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ITRK.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_LAND_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LAND.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_LAND_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LAND.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_LAND_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LAND.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_LAND_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LAND.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_IHG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IHG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_IHG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IHG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_IHG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IHG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_IHG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for IHG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_RR_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RR.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_RR_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RR.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_RR_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RR.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_RR_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RR.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ADML_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ADML.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ADML_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ADML.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ADML_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ADML.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ADML_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ADML.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_BKGH_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BKGH.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_BKGH_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BKGH.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_BKGH_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BKGH.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_BKGH_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for BKGH.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_SHEL_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SHEL.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_SHEL_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SHEL.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_SHEL_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SHEL.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_SHEL_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for SHEL.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_HIK_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HIK.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_HIK_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HIK.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_HIK_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HIK.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_HIK_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HIK.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_MNDI_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNDI.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_MNDI_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNDI.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_MNDI_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNDI.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_MNDI_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNDI.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_LMPL_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LMPL.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_LMPL_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LMPL.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_LMPL_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LMPL.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_LMPL_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for LMPL.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_RMV_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RMV.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_RMV_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RMV.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_RMV_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RMV.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_RMV_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for RMV.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_FRES_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FRES.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_FRES_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FRES.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_FRES_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FRES.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_FRES_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for FRES.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_PHNX_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PHNX.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_PHNX_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PHNX.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_PHNX_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PHNX.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_PHNX_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PHNX.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ENT_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ENT.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ENT_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ENT.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ENT_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ENT.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ENT_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ENT.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_ICAG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ICAG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_ICAG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ICAG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_ICAG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ICAG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_ICAG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for ICAG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_GLEN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GLEN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_GLEN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GLEN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_GLEN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GLEN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_GLEN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for GLEN.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_CCEPC_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCEPC.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_CCEPC_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCEPC.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_CCEPC_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCEPC.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_CCEPC_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCEPC.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_CCH_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCH.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_CCH_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCH.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_CCH_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCH.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_CCH_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CCH.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_PSHP_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSHP.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_PSHP_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSHP.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_PSHP_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSHP.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_PSHP_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for PSHP.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_AUTOA_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AUTOA.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_AUTOA_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AUTOA.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_AUTOA_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AUTOA.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_AUTOA_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AUTOA.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_MRON_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MRON.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_MRON_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MRON.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_MRON_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MRON.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_MRON_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MRON.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_CTEC_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CTEC.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_CTEC_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CTEC.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_CTEC_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CTEC.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_CTEC_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for CTEC.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_AAF_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAF.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_AAF_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAF.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_AAF_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAF.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_AAF_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for AAF.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_MNG_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNG.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_MNG_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNG.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_MNG_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNG.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_MNG_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for MNG.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_EDV_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EDV.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_EDV_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EDV.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_EDV_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EDV.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_EDV_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for EDV.L.xlsx', engine='openpyxl', sheet_name='Controversies')
ESG_Table_for_HLN_ENVIRONMENT = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLN.L.xlsx', engine='openpyxl', sheet_name='Environment')
ESG_Table_for_HLN_SOCIAL = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLN.L.xlsx', engine='openpyxl', sheet_name='Social')
ESG_Table_for_HLN_GOVERNANCE = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLN.L.xlsx', engine='openpyxl', sheet_name='Governance')
ESG_Table_for_HLN_CONTROVERSIES = pd.read_excel('/Users/tobifadeyi/Downloads/ESG/ESG TABLES/ESG Table for HLN.L.xlsx', engine='openpyxl', sheet_name='Controversies')

# %%
# Match only grade-based metrics
keyword_mapping = {
    "ESG Combined Score": "ESG Combined Score Grade",
    "ESG Score": "ESG Score Grade",
    "Environmental Pillar Score": "Environmental Pillar Score Grade",
    "Social Pillar Score": "Social Pillar Score Grade",
    "Governance Pillar Score": "Governance Pillar Score Grade"
}

def extract_scores_by_keyword(filepath):
    score_by_year = {}
    try:
        for sheet in ["Environment", "Social", "Governance", "Controversies"]:
            df = pd.read_excel(filepath, sheet_name=sheet, header=None, engine="openpyxl")
            if df.shape[0] < 12:
                continue
            years = df.iloc[4, 2:7].dropna().astype(int)
            metric_names = df.iloc[11:, 1].reset_index(drop=True)
            values = df.iloc[11:, 2:7].reset_index(drop=True)

            for i, col in enumerate(values.columns):
                year = years.iloc[i]
                if year not in score_by_year:
                    score_by_year[year] = {}
                for metric, val in zip(metric_names, values[col]):
                    if pd.notna(metric):
                        metric_str = str(metric).strip()
                        for keyword in keyword_mapping:
                            if keyword in metric_str:
                                score_by_year[year][keyword] = val
    except Exception as e:
        print(f"Error reading {filepath}: {e}")
    return score_by_year

def correct_years(combined_data_path, esg_folder_path, output_path):
    df = pd.read_csv(combined_data_path)
    df["Year (1)"] = pd.NA
    matched_years = {}

    for idx, row in df.iterrows():
        identifier = row["Identifier"]
        filepath = os.path.join(esg_folder_path, f"ESG Table for {identifier}.xlsx")
        if not os.path.exists(filepath):
            continue

        year_scores = extract_scores_by_keyword(filepath)
        for year, scores in year_scores.items():
            match = True
            for keyword, csv_col in keyword_mapping.items():
                csv_val = str(row[csv_col]).strip()
                file_val = str(scores.get(keyword, "")).strip()
                if pd.isna(row[csv_col]) or csv_val != file_val:
                    match = False
                    break
            if match:
                df.at[idx, "Year (1)"] = year
                break

    # Ensure unique years per identifier
    for ident, group in df.groupby("Identifier"):
        seen = set()
        for idx in group.index:
            year = df.at[idx, "Year (1)"]
            if pd.isna(year):
                continue
            original_year = int(year)
            new_year = original_year
            step = 0
            while new_year in seen:
                step += 1
                new_year = original_year - step
            df.at[idx, "Year (1)"] = new_year
            seen.add(new_year)

    df.to_csv(output_path, index=False)
    print(f"Saved corrected file to: {output_path}")

# %%
correct_years(
    combined_data_path="/Users/tobifadeyi/Documents/Thesis code/combined_data.csv",
    esg_folder_path="/Users/tobifadeyi/Downloads/ESG/ESG TABLES",
    output_path="/Users/tobifadeyi/Documents/Thesis code/combined_data_with_unique_years.csv"
)
# Out:
# Saved corrected file to: /Users/tobifadeyi/Documents/Thesis code/combined_data_with_unique_years.csv

# %%
unique_years = pd.read_csv("/Users/tobifadeyi/Documents/Thesis code/combined_data_with_unique_years.csv")

# %%
yr0.describe()
# Out:
#        Environmental Supply Chain Monitoring Score\n(FY0)  \
# count                                          60.000000
# mean                                           79.741297
# std                                             6.650288
# min                                            63.043478
# 25%                                            75.099791
# 50%                                            78.322164
# 75%                                            85.345738
# max                                            92.216359
#
#        Policy Water Efficiency Score\n(FY0)  \
# count                             95.000000
# mean                              54.979053
# std                               27.675517
# min                                0.000000
# 25%                               57.255245
# 50%                               66.464340
# 75%                               74.319728
# max                               80.552221
#
# ...

# %%
# To Show all rows
pd.set_option('display.max_rows', None)

# To Show all columns
pd.set_option('display.max_columns', None)

# To Prevent truncation of column content
pd.set_option('display.max_colwidth', None)

# %%
# Count empty columns in yr0
empty_columns = yr0.isna().all()
empty_column_count = empty_columns.sum()

# %%
# Identifying empty columns in yr0
empty_columns = yr0.columns[yr0.isna().all()]

# Converting to a list for easier readability
empty_columns_list = empty_columns.tolist()

print("Empty columns:")
print(empty_columns_list)
# Out:
# Empty columns:
# ['Cement Energy Use Score\n(FY0)', 'Estimated CO2 Equivalents Emission Total Score\n(FY0)', 'Cement CO2 Equivalents Emission Score\n(FY0)', 'Fleet Fuel Consumption Score\n(FY0)', 'Fleet CO2 Emissions Score\n(FY0)', 'GMO Products Score\n(FY0)', 'Animal Testing Score\n(FY0)', 'Strikes Score\n(FY0)', 'Embryonic Stem Cell Research Score\n(FY0)', 'Retailing Responsibility Score\n(FY0)', 'Revenue from Environmental Products Score\n(FY0)']

# %%
empty_columns_list
# Out:
# ['Cement Energy Use Score\n(FY0)',
#  'Estimated CO2 Equivalents Emission Total Score\n(FY0)',
#  'Cement CO2 Equivalents Emission Score\n(FY0)',
#  'Fleet Fuel Consumption Score\n(FY0)',
#  'Fleet CO2 Emissions Score\n(FY0)',
#  'GMO Products Score\n(FY0)',
#  'Animal Testing Score\n(FY0)',
#  'Strikes Score\n(FY0)',
#  'Embryonic Stem Cell Research Score\n(FY0)',
#  'Retailing Responsibility Score\n(FY0)',
#  'Revenue from Environmental Products Score\n(FY0)']

# %%
import sqlite3

# Create an in-memory SQLite database
conn = sqlite3.connect(':memory:')

# Renaming the original datasets to prevent altering the original data
yr0_copy = yr0.copy()
yr1_copy = yr1.copy()
yr2_copy = yr2.copy()
yr3_copy = yr3.copy()

# Adding a Year column to each dataset
yr0_copy['Year'] = 2025
yr1_copy['Year'] = 2024
yr2_copy['Year'] = 2023
yr3_copy['Year'] = 2022

# Removing 'FY' from column names
yr0_copy.columns = yr0_copy.columns.str.replace(r'\(FY.*\)', '', regex=True).str.strip()
yr1_copy.columns = yr1_copy.columns.str.replace(r'\(FY.*\)', '', regex=True).str.strip()
yr2_copy.columns = yr2_copy.columns.str.replace(r'\(FY.*\)', '', regex=True).str.strip()
yr3_copy.columns = yr3_copy.columns.str.replace(r'\(FY.*\)', '', regex=True).str.strip()

# Concatenating the datasets vertically
combined_df = pd.concat([yr0_copy, yr1_copy, yr2_copy, yr3_copy], ignore_index=True)

# Writing the combined DataFrame to a SQL table
combined_df.to_sql('combined_table', conn, if_exists='replace', index=False)

# Verifying the table creation by listing the tables
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print("Tables in the database:", cursor.fetchall())

# Previewing the combined table
cursor.execute("SELECT * FROM combined_table LIMIT 5;")
print("Preview of combined table:")
for row in cursor.fetchall():
    print(row)
# Out:
# Tables in the database: [('combined_table',)]
# Preview of combined table:
# ...

# %%
combined_df['Year (1)'] = unique_years['Year (1)']
# Out:
# /var/folders/fl/lv0hc01x58s_68_8g3k5dngc0000gn/T/ipykernel_19106/1630278419.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   combined_df['Year (1)'] = unique_years['Year (1)']

# %%
combined_df.head()
# Out:
#   Identifier                    Company Name     ISIN Code  \
# 0    ICGIN.L  Intermediate Capital Group PLC  GB00BYT1DJ19
# 1      III.L                    3i Group PLC  GB00B1YW4409
# 2      NWG.L               NatWest Group PLC  GB00BM8PJY71
# 3     BARC.L                    Barclays PLC  GB0031348658
# 4     HSBA.L               HSBC Holdings PLC  GB0005405286
#
#    Environmental Supply Chain Monitoring Score  Policy Water Efficiency Score  \
# 0                                    92.216359                       0.000000
# 1                                    92.207792                       0.000000
# 2                                    88.917263                       0.000000
# 3                                    88.414006                      77.754892
# 4                                    88.414006                      77.754892
#
#    Policy Energy Efficiency Score  Policy Sustainable Packaging Score  \
# ...

# %%
combined_df.to_csv('combined_data.csv', index=False)

# %%
# Percentage of missing values per column
missing_percent = combined_df.isnull().mean().sort_values(ascending=False)

# Show top 20 most missing columns
print(missing_percent.head(20))

# Visualize missing data (optional)
# Install missingno if not already installed
# %pip install missingno
# Out:
# GMO Products Score                                    1.0000
# Revenue from Environmental Products Score             1.0000
# Cement CO2 Equivalents Emission Score                 1.0000
# Fleet Fuel Consumption Score                          1.0000
# Fleet CO2 Emissions Score                             1.0000
# Animal Testing Score                                  1.0000
# Cement Energy Use Score                               1.0000
# Strikes Score                                         1.0000
# Estimated CO2 Equivalents Emission Total Score        1.0000
# Retailing Responsibility Score                        1.0000
# Embryonic Stem Cell Research Score                    1.0000
# Agrochemical Products Score                           0.9975
# Drug Delay Score                                      0.9925
# Labeled Wood Percentage Score                         0.9900
# Nuclear Production Score                              0.9900
# ...

# %%
# Count of each data type
print(combined_df.dtypes.value_counts())
# Out:
# float64    223
# object       8
# int64        1
# Name: count, dtype: int64

# %%
# List of object columns
print(combined_df.select_dtypes(include='object').columns)
# Out:
# Index(['Identifier', 'Company Name', 'ISIN Code',
#        'Governance Pillar Score Grade', 'Social Pillar Score Grade',
#        'ESG Combined Score Grade', 'Environmental Pillar Score Grade',
#        'ESG Score Grade'],
#       dtype='object')

# %%
targets = ['Environmental Pillar Score', 'Social Pillar Score', 'Governance Pillar Score']
print(combined_df[targets].describe())

# Histograms
combined_df[targets].hist(bins=20, figsize=(12, 5), edgecolor='black')
plt.suptitle("Distributions of ESG Pillar Scores")
plt.tight_layout()
plt.show()
# Out:
#        Environmental Pillar Score  Social Pillar Score  \
# count                  400.000000           400.000000
# mean                    66.404335            69.804867
# std                     21.313815            17.169778
# min                      0.000000            12.953500
# 25%                     52.455130            58.696762
# 50%                     71.645194            74.056213
# 75%                     82.167637            82.624787
# max                     96.054572            97.583775
#
#        Governance Pillar Score
# count               400.000000
# mean                 70.749245
# std                  17.942159
# min                  10.594291
# 25%                  61.347655
# 50%                  73.990558
# 75%                  84.325846
# max                  96.385706

# %%
# Keep only numeric columns
numeric_df = combined_df.select_dtypes(include='number')

# Compute correlation matrix
corr_matrix = numeric_df.corr()

# Correlation of all features with each ESG target
for target in targets:
    print(f"\nTop 10 correlated features with {target}:")
    print(corr_matrix[target].drop(target).sort_values(ascending=False).head(10))

# Visualize correlations between ESG scores
sns.pairplot(combined_df[targets])
plt.suptitle("Pairwise Plot of ESG Pillar Scores", y=1.02)
plt.show()
# Out:
# Top 10 correlated features with Environmental Pillar Score:
# Diseases of the Developing World Score                         0.967078
# Ozone-Depleting Substances Score                               0.899933
# Ozone-Depleting Substances To Revenues USD in million Score    0.899933
# ESG Score                                                      0.821086
# Labeled Wood Percentage Score                                  0.772877
# Sustainable Building Products Score                            0.711199
# Extractive Industries Transparency Initiative Score            0.691718
# Water Pollutant Emissions To Revenues USD Score                0.646956
# Social Pillar Score                                            0.634915
# Equator Principles or Env Project Financing Score              0.629850
# Name: Environmental Pillar Score, dtype: float64
#
# Top 10 correlated features with Social Pillar Score:
# Diseases of the Developing World Score                         0.940967
# ...

# %%
# Get absolute correlations with each target
top_corr_features = set()
for target in targets:
    top_corrs = corr_matrix[target].abs().sort_values(ascending=False).head(15).index
    top_corr_features.update(top_corrs)

# Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(combined_df[list(top_corr_features)].corr(), cmap='coolwarm', annot=False)
plt.title("Correlation Heatmap of Top ESG Features")
plt.show()

# %%
year_counts = combined_df['Year (1)'].value_counts()
print(year_counts)
# Out:
# Year (1)
# 2023.0    95
# 2022.0    95
# 2021.0    93
# 2024.0    66
# 2020.0    28
# 2025.0     1
# Name: count, dtype: int64

# %%
combined_df = combined_df[combined_df['Year (1)'] != 2025]

# %%
combined_df = combined_df.dropna(subset=['Year (1)'])

# %% [markdown]
#  # @hidden_cell.

# %%
# Boxplot of ESG scores by Year
plt.figure(figsize=(12, 6))
for i, target in enumerate(targets, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(x='Year (1)', y=target, data=combined_df)
    plt.title(f"{target} by Year")
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Replace empty instances in 'Year (1)' with values from 'Year'
unique_years['Year (1)'] = unique_years['Year (1)'].fillna(unique_years['Year'])

# Verify the changes
print(unique_years[['Year (1)', 'Year']].head())
# Out:
#    Year (1)  Year
# 0    2025.0  2025
# 1    2023.0  2025
# 2    2023.0  2025
# 3    2024.0  2025
# 4    2024.0  2025

# %%
unique_years
# Out:
#     Identifier                                  Company Name     ISIN Code  \
# 0      ICGIN.L                Intermediate Capital Group PLC  GB00BYT1DJ19
# 1        III.L                                  3i Group PLC  GB00B1YW4409
# 2        NWG.L                             NatWest Group PLC  GB00BM8PJY71
# 3       BARC.L                                  Barclays PLC  GB0031348658
# 4       HSBA.L                             HSBC Holdings PLC  GB0005405286
# 5       PSON.L                                   Pearson PLC  GB0006776081
# 6        WPP.L                                       WPP PLC  JE00B8KF9B49
# 7        HSX.L                                    Hiscox Ltd  BMG4593F1389
# 8       PHNX.L                    Phoenix Group Holdings PLC  GB00BGXQNP29
# 9        MNG.L                                       M&G PLC  GB00BKFB1C65
# 10      LGEN.L                     Legal & General Group PLC  GB0005603997
# ...

# %%
unique_years.to_csv('/Users/tobifadeyi/Documents/Thesis code/unique_years.csv', index=False)
